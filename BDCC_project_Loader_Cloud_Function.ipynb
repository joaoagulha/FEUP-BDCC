# %% [markdown]
# # BDCC project - Loader Cloud Function development
#
# **[Big Data and Cloud Computing](https://www.dcc.fc.up.pt/~edrdo/aulas/bdcc), DCC/FCUP**
#
# Make sure you go through the __[Google Cloud Functions Pub/Sub tutorial](https://cloud.google.com/functions/docs/tutorials/pubsub)__ before you start developing the LCF.

# %% [markdown]
# ## GCP authentication function

# %%
PROJECT_ID = 'bdcc20-p1'  # TODO change to your project id

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# The authentication method 
def google_colab_authenticate(projectId, keyFile=None, debug=True):  
    import os
    from google.colab import auth
    if keyFile == None:
      keyFile='/content/bdcc-colab.json'
    if os.access(keyFile,os.R_OK):
      if debug:
        print('Using key file "%s"' % keyFile)
      os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '%s' % keyFile
      os.environ['GCP_PROJECT'] = projectId 
      os.environ['GCP_ACCOUNT'] = 'bdcc-colab@' + projectId + '.iam.gserviceaccount.com'
      # !gcloud auth activate-service-account --key-file="$GOOGLE_APPLICATION_CREDENTIALS" --project="$GCP_PROJECT"
    else:
      if debug:
        print('No key file given. You may be redirected to the verification code procedure.')
      auth.authenticate_user()
      # !gcloud config set project $projectId
    # !gcloud info | grep -e Account -e Project

# Copy key file from Google Drive if available 
# to a path without spaces (it usually creates problems)
# !test -f "/content/drive/My Drive/bdcc-colab.json" && cp "/content/drive/My Drive/bdcc-colab.json" /content/bdcc-colab.json
google_colab_authenticate(PROJECT_ID)
# Out:
# Using key file "/content/bdcc-colab.json"
# Activated service account credentials for: [bdcc-cloud@bdcc20-p1.iam.gserviceaccount.com]
# Account: [bdcc-cloud@bdcc20-p1.iam.gserviceaccount.com]
# Project: [bdcc20-p1]

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/drive/My Drive/bdcc-colab.json' 
# !echo $GOOGLE_APPLICATION_CREDENTIALS
# Out:
# /content/drive/My Drive/bdcc-colab.json

# %%
from google.cloud import storage

storage_client = storage.Client()
buckets = storage_client.list_buckets()
print('-- List of buckets in project \"' + storage_client.project + '\"')

for b in buckets:
  print(b.name)
# Out:
# -- List of buckets in project "bdcc20-p1"
# bdcc20-movie_data

# %%
# To enable the GPU access Edit > Notebook settings and set the Hardware accelerator to GPU.

# %tensorflow_version 2.x 
import tensorflow as tf

print("GPU device: " + tf.test.gpu_device_name())

from tensorflow.python.client import device_lib

tf_devices = device_lib.list_local_devices()

for x in tf_devices:
  print('------')
  print(x)
# Out:
# GPU device:
# ------
# name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8945757363232109252
#
# ------
# name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7364822986433981580
# physical_device_desc: "device: XLA_CPU device"

# %% [markdown]
# ## Cloud function code
#
# This should be placed in a single cell to facilitate cloud function.
#
# Note that you cannot use "magic" notebook extensions such as `! shell command` or `%%bigquery`.

# %%
# Imports
import base64
import pandas as pd
import os
import tempfile
import time
from zipfile import ZipFile
import google.cloud.bigquery as bq
import google.cloud.storage as gcs


# Parameters
PROJECT_ID = 'bdcc20-p1'  # TODO change to your project id
BUCKET_NAME = 'bdcc20-movie_data' # TODO change to your bucket name
PUBSUB_TOPIC = 'dispatcher' 
SUB_DIRECTORY = 'bdcc1920_project_outputs'
OUTPUT_ZIP_FILE = 'output.zip'

DEBUG = True 
RUNNING_IN_COLAB = os.environ.get('COLAB_GPU') != None

TMP_DIR=tempfile.mkdtemp(prefix='LCF_')

# Debug method
def debug(message):
  if DEBUG:
     print(message)

# Authenticate to GCP if running in Colab
if RUNNING_IN_COLAB:
  google_colab_authenticate(PROJECT_ID)

# Initialize interface to BigQuery and GCS
BQ_CLIENT = bq.Client(PROJECT_ID)
GCS_CLIENT = gcs.Client(PROJECT_ID)
BUCKET = gcs.Bucket(GCS_CLIENT, BUCKET_NAME)

def get_data_from_cloud_storage(dataset_id):
  bucket_path = '%s/%s/%s' % (SUB_DIRECTORY, dataset_id, OUTPUT_ZIP_FILE)
  local_zip_file = '%s/%s' % (TMP_DIR, OUTPUT_ZIP_FILE)
  debug('Downloading gs://%s/%s to %s' % (BUCKET_NAME,bucket_path,local_zip_file))
  blob = gcs.Blob(bucket_path, BUCKET)
  with open(local_zip_file, 'wb') as out:
    blob.download_to_file(out)
  

def unzip_data_file():
  local_zip_file = '%s/%s' % (TMP_DIR, OUTPUT_ZIP_FILE)
  debug('Unzipping %s' % local_zip_file)
  with ZipFile(local_zip_file) as zf:
    zf.extractall(TMP_DIR)
  debug('Unzipping done')

def load_movie_agg_data(dataset_id):
  tid = 'movies_agg'
  table_name = '%s.%s.%s' % (PROJECT_ID, dataset_id, tid)
  
  # Read parquet file
  parquet_files_path = '%s/%s.parquet' % (TMP_DIR, tid)
  debug('Reading Parquet files from %s' % parquet_files_path)
  pdf = pd.read_parquet(parquet_files_path)
  debug(str(pdf.head(5)))


  # Create BigQuery table
  table = bq.Table(table_name)
  
  table.schema = (
        bq.SchemaField("movieId", "INTEGER", "REQUIRED"),
        bq.SchemaField("title",  "STRING", "REQUIRED"),
        bq.SchemaField("year", "INTEGER", "REQUIRED"),
        bq.SchemaField("imdbId", "INTEGER", "REQUIRED"),
        bq.SchemaField("numRatings", "INTEGER", "REQUIRED"),
        bq.SchemaField("avgRating", "FLOAT", "REQUIRED"),
  )
  debug('Creating %s' % table_name)
  BQ_CLIENT.create_table(table)

  debug('Populating %s with %d rows' % (table_name, len(pdf)))
  load_job = BQ_CLIENT.load_table_from_dataframe(pdf, table)

  while load_job.running():
     debug('waiting for load job to complete')
     time.sleep(1)

  debug('Done with table %s' % table_name)

def load_tfidf_data(dataset_id):
  tid = 'tfidf'
  table_name = '%s.%s.%s' % (PROJECT_ID, dataset_id, tid)
  
  # Read parquet file
  parquet_files_path = '%s/%s.parquet' % (TMP_DIR, tid)
  debug('Reading Parquet files from %s' % parquet_files_path)
  pdf = pd.read_parquet(parquet_files_path)
  debug(str(pdf.head(5)))


  # Create BigQuery table
  table = bq.Table(table_name)
  
  table.schema = (
        bq.SchemaField("word", "STRING", "REQUIRED"),
        bq.SchemaField("movieId",  "INTEGER", "REQUIRED"),
        bq.SchemaField("tfidf", "FLOAT", "REQUIRED"),
  )
  debug('Creating %s' % table_name)
  BQ_CLIENT.create_table(table)

  debug('Populating %s with %d rows' % (table_name, len(pdf)))
  load_job = BQ_CLIENT.load_table_from_dataframe(pdf, table)

  while load_job.running():
     debug('waiting for load job to complete')
     time.sleep(1)

  debug('Done with table %s' % table_name)


def load_jaccard_index_data(dataset_id):
  tid = 'jaccardIndex'
  table_name = '%s.%s.%s' % (PROJECT_ID, dataset_id, tid)
  
  # Read parquet file
  parquet_files_path = '%s/%s.parquet' % (TMP_DIR, tid)
  debug('Reading Parquet files from %s' % parquet_files_path)
  pdf = pd.read_parquet(parquet_files_path)
  debug(str(pdf.head(5)))


  # Create BigQuery table
  table = bq.Table(table_name)
  
  table.schema = (
        bq.SchemaField("movie1", "INTEGER", "REQUIRED"),
        bq.SchemaField("movie2",  "INTEGER", "REQUIRED"),
        bq.SchemaField("user", "INTEGER", "REQUIRED"),
        bq.SchemaField("index", "INTEGER", "REQUIRED"),
        bq.SchemaField("jaccard_index", "FLOAT", "REQUIRED"),
  )
  debug('Creating %s' % table_name)
  BQ_CLIENT.create_table(table)

  debug('Populating %s with %d rows' % (table_name, len(pdf)))
  load_job = BQ_CLIENT.load_table_from_dataframe(pdf, table)

  while load_job.running():
     debug('waiting for load job to complete')
     time.sleep(1)

  debug('Done with table %s' % table_name)

def handle_pubsub_message(event, context):
  debug('Event: %s' % event)
  debug('Context: %s' % context)

  if RUNNING_IN_COLAB:
    dataset_id = event['data']
  else:
    dataset_id =  base64.b64decode(event['data']).decode('utf-8')
  
  debug('Dataset: %s' % dataset_id)
  
  get_data_from_cloud_storage(dataset_id)
  unzip_data_file()
  print(dataset_id)

  debug('Deleting previous BiqQuery dataset (if any)')

  print(dataset_id)
  BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
  BQ_CLIENT.create_dataset(dataset_id)

  debug('Created BiqQuery dataset')

  load_movie_agg_data(dataset_id)
  load_tfidf_data(dataset_id)
  load_jaccard_index_data(dataset_id) # bonus
  debug('Done for data set %s' % dataset_id)
# Out:
# Using key file "/content/bdcc-colab.json"
# Activated service account credentials for: [bdcc-cloud@bdcc20-p1.iam.gserviceaccount.com]
# Account: [bdcc-cloud@bdcc20-p1.iam.gserviceaccount.com]
# Project: [bdcc20-p1]

# %% [markdown]
# ## Test cloud function locally

# %%
# !gsutil ls gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1
# Out:
# gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1/output.zip
# gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/
# gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1/movies_agg.parquet/
# gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1/tfidf.parquet/

# %%
BUCKET = gcs.Bucket(GCS_CLIENT, BUCKET_NAME)
list_of_blobs = BUCKET.list_blobs(prefix=SUB_DIRECTORY)
for blob in list_of_blobs:
  print('==> ' + blob.id)
# Out:
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/._SUCCESS.crc/1586251143340792
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00000-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137880750
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00001-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139861421
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00002-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138733352
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00003-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134717107
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00004-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137331425
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00005-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135218119
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00006-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141810278
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00007-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134198725
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00008-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139758209
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00009-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139470840
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00010-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139147772
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00011-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142538674
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00012-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139230665
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00013-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135947179
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00014-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138159035
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00015-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134505476
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00016-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138864057
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00017-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134826835
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00018-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140056015
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00019-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136190827
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00020-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137231007
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00021-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141925642
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00022-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137511642
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00023-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140411238
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00024-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144114358
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00025-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133886308
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00026-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135398779
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00027-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136640458
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00028-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144052187
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00029-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138332303
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00030-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135348835
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00031-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136408507
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00032-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135574900
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00033-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138663641
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00034-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138358231
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00035-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140409163
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00036-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140397446
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00037-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137017198
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00038-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142452367
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00039-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137875966
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00040-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142478937
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00041-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141887763
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00042-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141876228
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00043-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136008496
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00044-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138020174
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00045-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139576999
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00046-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143294526
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00047-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133945114
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00048-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140413178
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00049-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140069684
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00050-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142999777
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00051-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144270723
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00052-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137382926
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00053-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143791051
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00054-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137371393
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00055-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142504259
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00056-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138076879
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00057-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144147835
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00058-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140991686
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00059-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141003954
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00060-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134823917
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00061-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135708963
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00062-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138505158
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00063-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136575880
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00064-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137363752
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00065-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144458854
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00066-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135967843
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00067-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142040032
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00068-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137121599
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00069-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133655470
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00070-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139160614
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00071-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138196781
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00072-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140898293
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00073-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142184794
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00074-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134827085
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00075-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141556266
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00076-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138599094
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00077-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142835217
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00078-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136357478
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00079-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142476595
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00080-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133651644
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00081-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139146837
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00082-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140736083
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00083-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133681309
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00084-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136890614
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00085-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143874804
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00086-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135732574
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00087-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139157423
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00088-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135134961
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00089-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135727443
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00090-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139773098
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00091-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134722270
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00092-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138604528
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00093-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138921191
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00094-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141376813
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00095-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136594661
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00096-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141865170
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00097-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135107950
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00098-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143215815
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00099-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140722993
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00100-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141579885
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00101-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134180942
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00102-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137512849
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00103-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143886853
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00104-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142523406
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00105-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139492044
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00106-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140991846
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00107-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141289427
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00108-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137598791
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00109-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135903457
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00110-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138836743
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00111-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136138069
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00112-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143950621
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00113-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134517308
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00114-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134562057
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00115-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138154433
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00116-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136038801
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00117-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137632689
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00118-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137574785
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00119-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139438885
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00120-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140096620
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00121-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141899402
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00122-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139205851
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00123-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143486179
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00124-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138687141
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00125-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138143641
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00126-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144151784
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00127-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140099132
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00128-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143258587
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00129-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141270408
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00130-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141988687
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00131-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136972039
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00132-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136011388
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00133-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144204099
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00134-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143004628
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00135-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140051510
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00136-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134506476
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00137-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137882266
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00138-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138967923
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00139-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137688548
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00140-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139110394
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00141-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141597739
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00142-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143764954
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00143-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144201829
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00144-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141014112
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00145-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134522719
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00146-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134267445
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00147-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139159028
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00148-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142470868
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00149-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134237916
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00150-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141000114
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00151-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133681326
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00152-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140429841
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00153-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142168768
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00154-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143614291
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00155-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135130836
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00156-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136541948
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00157-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137012262
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00158-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139434319
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00159-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137266536
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00160-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133611552
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00161-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135699221
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00162-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133945729
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00163-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143605670
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00164-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251144035953
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00165-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137765743
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00166-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136784885
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00167-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251137267022
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00168-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135435848
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00169-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141317132
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00170-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133903885
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00171-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143331814
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00172-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136644806
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00173-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138643927
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00174-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141332246
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00175-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135479167
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00176-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134345051
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00177-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143050918
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00178-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141325144
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00179-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133935640
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00180-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143861891
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00181-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251141846922
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00182-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135805177
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00183-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251133596184
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00184-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138386976
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00185-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140714952
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00186-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251139745100
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00187-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142194903
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00188-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251142175675
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00189-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136760755
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00190-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136352685
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00191-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135399748
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00192-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135126572
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00193-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251140981373
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00194-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134526021
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00195-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251143062089
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00196-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251138810994
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00197-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251134197446
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00198-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251135678349
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/.part-00199-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet.crc/1586251136478244
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/_SUCCESS/1586251135097847
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00000-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141891331
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00001-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251135406637
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00002-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251135718536
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00003-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137323171
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00004-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143665633
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00005-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140710266
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00006-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143621758
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00007-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140715815
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00008-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139455720
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00009-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251138167223
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00010-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142272864
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00011-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137511574
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00012-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139748411
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00013-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136484530
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00014-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140142247
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00015-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136840538
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00016-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251134904179
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00017-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140411105
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00018-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139449456
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00019-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143967628
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00020-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136007747
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00021-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143325090
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00022-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136403246
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00023-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251135395648
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00024-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251134241896
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00025-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143286037
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00026-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141250953
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00027-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133938450
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00028-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140049472
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00029-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142959406
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00030-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251138032670
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00031-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143082392
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00032-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136349097
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00033-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139432493
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00034-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137124207
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00035-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133922333
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00036-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141029218
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00037-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141556519
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00038-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140097279
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00039-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137063179
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00040-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142766566
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00041-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137315289
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00042-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140449004
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00043-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141146836
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00044-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251134471083
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00045-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133602449
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00046-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139755502
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00047-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142749764
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00048-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133901339
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00049-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251144385137
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00050-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136299142
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00051-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136296775
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00052-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137767172
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00053-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142221586
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00054-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133889413
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00055-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251138345634
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00056-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133617402
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00057-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251138928202
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00058-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251135112737
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00059-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141125888
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00060-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141884665
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00061-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143332999
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00062-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143008666
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00063-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139912481
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00064-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141601667
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00065-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137133874
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00066-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142714338
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00067-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141268412
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00068-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251134959996
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00069-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140641201
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00070-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143842042
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00071-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251135398765
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00072-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140364464
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00073-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139684444
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00074-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143604834
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00075-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251142794237
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00076-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137052486
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00077-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251140710292
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00078-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251139770264
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00079-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137027481
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00080-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251144433158
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00081-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251141502981
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00082-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251138336428
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00083-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251137832293
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00084-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136816450
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00085-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251133647431
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00086-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251134193292
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00087-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143890105
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00088-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251143894803
# ==> bdcc20-movie_data/bdcc1920_project_outputs/medium1/jaccardIndex.parquet/part-00089-9ae7e81c-7872-462b-b758-fe9bc79b7a5d-c000.snappy.parquet/1586251136726670
# ...
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet.crc/1585656983463770
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet.crc/1585668399378689
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet.crc/1585663390071970
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet.crc/1585936152781302
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet.crc/1585671828308174
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet.crc/1585945459362423
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet.crc/1585652501881562
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/.part-00183-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet.crc/1585935926597606
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/_SUCCESS/1585945459564532
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983005167
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399366937
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663390475813
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152846962
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671828367692
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459278432
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501356329
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00000-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926975840
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983453008
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399891226
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389586907
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152831799
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827931344
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459019820
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501340556
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00004-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926609785
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983408837
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668400330198
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389998259
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152478244
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827457645
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459631822
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501328678
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00022-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926961940
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983919015
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399818474
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389598476
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152721567
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827926638
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459040632
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501739529
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00074-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926603241
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983895916
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399378137
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663390054999
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152728262
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827463813
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459606432
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501342739
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00107-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926974760
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656982970694
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399832637
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389577798
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152981504
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827959599
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459367760
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501804719
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00114-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926853086
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656982964629
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399383975
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389640581
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152506378
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827468582
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459330855
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501815740
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00115-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935927284835
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983409564
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399882858
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389558956
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152477029
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827479728
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459368420
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501359772
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00123-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926755725
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983898882
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399882531
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663389604358
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152526546
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827938784
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459054077
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652502227273
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00130-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935927298107
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656982957233
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668400290693
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663390143590
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936153019192
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827930548
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459630120
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652502154867
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00133-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935926598799
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983005413
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399378336
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663390481592
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936153081038
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671828362756
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459029185
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501320219
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00150-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935927038853
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-1c08585b-d369-486f-aa83-95bccd1dc03b-c000.snappy.parquet/1585656983479427
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-321d0dc5-8f4c-426d-9816-957a8b4055a9-c000.snappy.parquet/1585668399875559
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-419c7af0-ca47-4909-9600-c692127e09dc-c000.snappy.parquet/1585663390059310
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-75a63e30-2d63-456f-93b4-1f351c2401c2-c000.snappy.parquet/1585936152462499
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-8436c2f2-0377-467d-aad5-b28eb65c7cda-c000.snappy.parquet/1585671827489111
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-94668085-9406-4c6b-b4a0-cdfa0316fc05-c000.snappy.parquet/1585945459340021
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-a9b6a721-6e5a-43da-aae9-a6f2a891edf9-c000.snappy.parquet/1585652501814924
# ==> bdcc20-movie_data/bdcc1920_project_outputs/tiny1/tfidf.parquet/part-00183-f534fa55-aa1e-4036-972e-b5764ee42bd8-c000.snappy.parquet/1585935927313613

# %%
dataset = 'medium1' #@param ["tiny1", "tiny2", "tiny3", "tiny4", "medium1", "medium2", "medium3", "medium4", "large1", "large2", "large3", "large4", "large5"] {allow-input: true}
handle_pubsub_message({ 'data': dataset}, None)
# Out:
# Event: {'data': 'medium1'}
# Context: None
# Dataset: medium1
# Downloading gs://bdcc20-movie_data/bdcc1920_project_outputs/medium1/output.zip to /tmp/LCF_fhfsm2p4/output.zip
# Unzipping /tmp/LCF_fhfsm2p4/output.zip
# Unzipping done
# medium1
# Deleting previous BiqQuery dataset (if any)
# medium1
# Created BiqQuery dataset
# Reading Parquet files from /tmp/LCF_fhfsm2p4/movies_agg.parquet
#    movieId  ... avgRating
# 0       24  ...  3.179306
# 1      888  ...  2.319775
# 2      944  ...  3.819965
# 3     1102  ...  2.610465
# 4     1176  ...  3.889452
#
# [5 rows x 6 columns]
# Creating bdcc20-p1.medium1.movies_agg
# Populating bdcc20-p1.medium1.movies_agg with 328 rows
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# Done with table bdcc20-p1.medium1.movies_agg
# Reading Parquet files from /tmp/LCF_fhfsm2p4/tfidf.parquet
#                word  movieId     tfidf
# 0   dying and death    48043  0.082040
# 1  aftermath of war     1939  1.344348
# 2          hostages     2058  1.440373
# 3         dystopian    38881  8.066089
# 4   police violence    38881  2.688696
# Creating bdcc20-p1.medium1.tfidf
# Populating bdcc20-p1.medium1.tfidf with 3064 rows
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# Done with table bdcc20-p1.medium1.tfidf
# Reading Parquet files from /tmp/LCF_fhfsm2p4/jaccardIndex.parquet
#    movie1  movie2   user  index  jaccard_index
# 0    2890    3052  16063   1881       0.117101
# 1    4720   68157  22114   1860       0.084110
# 2    3052   68157  24985   1801       0.072083
# 3    3052    3408  19141   1701       0.088867
# 4    3408    4720  16487   1543       0.093589
# Creating bdcc20-p1.medium1.jaccardIndex
# Populating bdcc20-p1.medium1.jaccardIndex with 3321 rows
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# waiting for load job to complete
# Done with table bdcc20-p1.medium1.jaccardIndex
# Done for data set medium1

# %% [markdown]
# ## Trigger cloud function once it is deployed

# %% [markdown]
# Before deployment do not forget to add the following dependencies to __REQUIREMENTS.txt__ in the function definitions (note that __pyarrow__ is required for Parquet data handling using Pandas):
#
# ```
# pyarrow
# pandas
# google.cloud.bigquery
# google.cloud.storage
# ```

# %%
dataset = 'medium1' #@param ["tiny1", "tiny2", "tiny3", "tiny4", "medium1", "medium2", "medium3", "medium4", "large1", "large2", "large3", "large4", "large5"] {allow-input: true}
# !gcloud pubsub topics publish "$PUBSUB_TOPIC" --message "$dataset"
# Out:
# messageIds:
# - '1095662293375688'

# %%
# TODO You may now check, as in previous notebooks:
# - inspect function logs
# - your BigQuery data is ok with some queries in the notebook and/or in the BigQuery Web UI

# %%
# !gcloud functions logs read loader_cloud_function
# Out:
# LEVEL  NAME                   EXECUTION_ID      TIME_UTC                 LOG
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:36.453  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:37.493  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:38.566  Done with table bdcc20-p1.medium1.tfidf
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:38.566  Reading Parquet files from /tmp/LCF_6jysbvd3/jaccardIndex.parquet
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599     movie1  movie2   user  index  jaccard_index
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  0    2890    3052  16063   1881       0.117101
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  1    4720   68157  22114   1860       0.084110
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  2    3052   68157  24985   1801       0.072083
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  3    3052    3408  19141   1701       0.088867
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  4    3408    4720  16487   1543       0.093589
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.599  Creating bdcc20-p1.medium1.jaccardIndex
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:39.759  Populating bdcc20-p1.medium1.jaccardIndex with 3321 rows
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:40.758  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:41.862  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:42.927  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:43.999  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:45.066  waiting for load job to complete
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:46.137  Done with table bdcc20-p1.medium1.jaccardIndex
# I      loader_cloud_function  1095649122874450  2020-04-07 09:19:46.137  Done for data set medium1
# D      loader_cloud_function  1095649122874450  2020-04-07 09:19:46.140  Function execution took 32725 ms, finished with status: 'ok'

# %%
cloudFunctionName = 'loader_cloud_function'
# !gcloud functions logs read $cloudFunctionName --limit 1000
# Out:
# LEVEL  NAME                   EXECUTION_ID      TIME_UTC                 LOG
# D      loader_cloud_function  1087417895409978  2020-03-31 13:44:02.999  Function execution started
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:08.908  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:08.908  Context: {event_id: 1087417895409978, timestamp: 2020-03-31T13:43:55.064Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:08.908  Dataset: tiny1
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:08.908  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_9hne5g8_/output.zip
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:09.243  Unzipping /tmp/LCF_9hne5g8_/output.zip
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:09.249  Unzipping done
# I      loader_cloud_function  1087417895409978  2020-03-31 13:44:09.249  Deleting previous BiqQuery dataset (if any)
# E      loader_cloud_function  1087417895409978  2020-03-31 13:44:09.432  Traceback (most recent call last):
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 383, in run_background_function
#                                                                              _function_handler.invoke_user_function(event_object)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 217, in invoke_user_function
#                                                                              return call_user_function(request_or_event)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 214, in call_user_function
#                                                                              event_context.Context(**request_or_event.context))
#                                                                            File "/user_code/main.py", line 107, in handle_pubsub_message
#                                                                              BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 1119, in delete_dataset
#                                                                              timeout=timeout,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 556, in _call_api
#                                                                              return call()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 286, in retry_wrapped_func
#                                                                              on_error=on_error,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 184, in retry_target
#                                                                              return target()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/_http.py", line 423, in api_request
#                                                                              raise exceptions.from_http_response(response)
#                                                                          google.api_core.exceptions.Forbidden: 403 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/bdcc20-p1/datasets/tiny1?deleteContents=true: Access Denied: Dataset bdcc20-p1:tiny1: User does not have bigquery.datasets.delete permission for dataset bdcc20-p1:tiny1.
# D      loader_cloud_function  1087417895409978  2020-03-31 13:44:09.436  Function execution took 6439 ms, finished with status: 'crash'
# D      loader_cloud_function  1087463345761693  2020-03-31 14:03:22.873  Function execution started
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:28.415  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:28.415  Context: {event_id: 1087463345761693, timestamp: 2020-03-31T14:03:17.764Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:28.415  Dataset: tiny1
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:28.415  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_7s831jr6/output.zip
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:29.086  Unzipping /tmp/LCF_7s831jr6/output.zip
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:29.163  Unzipping done
# I      loader_cloud_function  1087463345761693  2020-03-31 14:03:29.163  Deleting previous BiqQuery dataset (if any)
# E      loader_cloud_function  1087463345761693  2020-03-31 14:03:29.331  Traceback (most recent call last):
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 383, in run_background_function
#                                                                              _function_handler.invoke_user_function(event_object)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 217, in invoke_user_function
#                                                                              return call_user_function(request_or_event)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 214, in call_user_function
#                                                                              event_context.Context(**request_or_event.context))
#                                                                            File "/user_code/main.py", line 107, in handle_pubsub_message
#                                                                              BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 1119, in delete_dataset
#                                                                              timeout=timeout,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 556, in _call_api
#                                                                              return call()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 286, in retry_wrapped_func
#                                                                              on_error=on_error,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 184, in retry_target
#                                                                              return target()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/_http.py", line 423, in api_request
#                                                                              raise exceptions.from_http_response(response)
#                                                                          google.api_core.exceptions.Forbidden: 403 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/bdcc20-p1/datasets/tiny1?deleteContents=true: Access Denied: Dataset bdcc20-p1:tiny1: User does not have bigquery.datasets.delete permission for dataset bdcc20-p1:tiny1.
# D      loader_cloud_function  1087463345761693  2020-03-31 14:03:29.333  Function execution took 6462 ms, finished with status: 'crash'
# D      loader_cloud_function  1087484801161743  2020-03-31 14:17:30.598  Function execution started
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:36.743  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:36.743  Context: {event_id: 1087484801161743, timestamp: 2020-03-31T14:17:24.293Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:36.743  Dataset: tiny1
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:36.743  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_cwc0pexf/output.zip
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:37.127  Unzipping /tmp/LCF_cwc0pexf/output.zip
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:37.165  Unzipping done
# I      loader_cloud_function  1087484801161743  2020-03-31 14:17:37.165  Deleting previous BiqQuery dataset (if any)
# E      loader_cloud_function  1087484801161743  2020-03-31 14:17:37.445  Traceback (most recent call last):
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 383, in run_background_function
#                                                                              _function_handler.invoke_user_function(event_object)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 217, in invoke_user_function
#                                                                              return call_user_function(request_or_event)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 214, in call_user_function
#                                                                              event_context.Context(**request_or_event.context))
#                                                                            File "/user_code/main.py", line 107, in handle_pubsub_message
#                                                                              BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 1119, in delete_dataset
#                                                                              timeout=timeout,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 556, in _call_api
#                                                                              return call()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 286, in retry_wrapped_func
#                                                                              on_error=on_error,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 184, in retry_target
#                                                                              return target()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/_http.py", line 423, in api_request
#                                                                              raise exceptions.from_http_response(response)
#                                                                          google.api_core.exceptions.Forbidden: 403 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/bdcc20-p1/datasets/tiny1?deleteContents=true: Access Denied: Dataset bdcc20-p1:tiny1: User does not have bigquery.datasets.delete permission for dataset bdcc20-p1:tiny1.
# D      loader_cloud_function  1087484801161743  2020-03-31 14:17:37.450  Function execution took 6853 ms, finished with status: 'crash'
# D      loader_cloud_function  1087548964581600  2020-03-31 15:02:27.227  Function execution started
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.394  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.394  Context: {event_id: 1087548964581600, timestamp: 2020-03-31T15:02:21.877Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.394  Dataset: tiny1
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.394  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_vez81lws/output.zip
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.723  Unzipping /tmp/LCF_vez81lws/output.zip
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.728  Unzipping done
# I      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.728  Deleting previous BiqQuery dataset (if any)
# E      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.947  Traceback (most recent call last):
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 383, in run_background_function
#                                                                              _function_handler.invoke_user_function(event_object)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 217, in invoke_user_function
#                                                                              return call_user_function(request_or_event)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 214, in call_user_function
#                                                                              event_context.Context(**request_or_event.context))
#                                                                            File "/user_code/main.py", line 107, in handle_pubsub_message
#                                                                              BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 1119, in delete_dataset
#                                                                              timeout=timeout,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 556, in _call_api
#                                                                              return call()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 286, in retry_wrapped_func
#                                                                              on_error=on_error,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 184, in retry_target
#                                                                              return target()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/_http.py", line 423, in api_request
#                                                                              raise exceptions.from_http_response(response)
#                                                                          google.api_core.exceptions.Forbidden: 403 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/bdcc20-p1/datasets/tiny1?deleteContents=true: Access Denied: Dataset bdcc20-p1:tiny1: User does not have bigquery.datasets.delete permission for dataset bdcc20-p1:tiny1.
# D      loader_cloud_function  1087548964581600  2020-03-31 15:02:33.951  Function execution took 6726 ms, finished with status: 'crash'
# D      loader_cloud_function  1077308930847808  2020-03-31 15:07:38.115  Function execution started
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.132  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.132  Context: {event_id: 1077308930847808, timestamp: 2020-03-31T15:07:30.769Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.132  Dataset: tiny1
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.132  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_4bpnwmmv/output.zip
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.392  Unzipping /tmp/LCF_4bpnwmmv/output.zip
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.397  Unzipping done
# I      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.397  Deleting previous BiqQuery dataset (if any)
# E      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.538  Traceback (most recent call last):
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 383, in run_background_function
#                                                                              _function_handler.invoke_user_function(event_object)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 217, in invoke_user_function
#                                                                              return call_user_function(request_or_event)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/functions/worker.py", line 214, in call_user_function
#                                                                              event_context.Context(**request_or_event.context))
#                                                                            File "/user_code/main.py", line 107, in handle_pubsub_message
#                                                                              BQ_CLIENT.delete_dataset(dataset_id, delete_contents = True, not_found_ok = True)
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 1119, in delete_dataset
#                                                                              timeout=timeout,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/bigquery/client.py", line 556, in _call_api
#                                                                              return call()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 286, in retry_wrapped_func
#                                                                              on_error=on_error,
#                                                                            File "/env/local/lib/python3.7/site-packages/google/api_core/retry.py", line 184, in retry_target
#                                                                              return target()
#                                                                            File "/env/local/lib/python3.7/site-packages/google/cloud/_http.py", line 423, in api_request
#                                                                              raise exceptions.from_http_response(response)
#                                                                          google.api_core.exceptions.Forbidden: 403 DELETE https://bigquery.googleapis.com/bigquery/v2/projects/bdcc20-p1/datasets/tiny1?deleteContents=true: Access Denied: Dataset bdcc20-p1:tiny1: User does not have bigquery.datasets.delete permission for dataset bdcc20-p1:tiny1.
# D      loader_cloud_function  1077308930847808  2020-03-31 15:07:44.541  Function execution took 6427 ms, finished with status: 'crash'
# D      loader_cloud_function  1087549301253402  2020-03-31 15:11:42.978  Function execution started
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.495  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.496  Context: {event_id: 1087549301253402, timestamp: 2020-03-31T15:11:37.996Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.496  Dataset: tiny1
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.496  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.807  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.863  Unzipping done
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:48.863  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.459  Created BiqQuery dataset
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.459  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  1        2                      Jumanji  1995  113497         110   3.431818
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  2        3             Grumpier Old Men  1995  113228          52   3.259615
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  3        4            Waiting to Exhale  1995  114885           7   2.357143
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  4        5  Father of the Bride Part II  1995  113041          49   3.071429
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.607  Creating bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:49.815  Populating bdcc20-p1.tiny1.movies_agg with 10 rows
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:51.564  waiting for load job to complete
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:52.660  waiting for load job to complete
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:53.735  waiting for load job to complete
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:54.821  waiting for load job to complete
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:55.890  waiting for load job to complete
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:57.031  Done with table bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:57.031  tfidf data loading is not implemented!
# I      loader_cloud_function  1087549301253402  2020-03-31 15:11:57.031  Done for data set tiny1
# D      loader_cloud_function  1087549301253402  2020-03-31 15:11:57.035  Function execution took 14059 ms, finished with status: 'ok'
# D      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.663  Function execution started
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.674  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.674  Context: {event_id: 1087550121215275, timestamp: 2020-03-31T15:15:11.918Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.674  Dataset: tiny1
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.674  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.684  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.758  Unzipping done
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:12.758  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.291  Created BiqQuery dataset
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.291  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  1        2                      Jumanji  1995  113497         110   3.431818
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  2        3             Grumpier Old Men  1995  113228          52   3.259615
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  3        4            Waiting to Exhale  1995  114885           7   2.357143
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  4        5  Father of the Bride Part II  1995  113041          49   3.071429
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.386  Creating bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:13.638  Populating bdcc20-p1.tiny1.movies_agg with 10 rows
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:15.223  waiting for load job to complete
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:16.397  waiting for load job to complete
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:17.530  waiting for load job to complete
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:18.746  waiting for load job to complete
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:19.848  Done with table bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:19.848  tfidf data loading is not implemented!
# I      loader_cloud_function  1087550121215275  2020-03-31 15:15:19.848  Done for data set tiny1
# D      loader_cloud_function  1087550121215275  2020-03-31 15:15:19.852  Function execution took 7189 ms, finished with status: 'ok'
# D      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.832  Function execution started
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.872  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.872  Context: {event_id: 1087568208062703, timestamp: 2020-03-31T15:17:03.405Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.872  Dataset: tiny1
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.872  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.884  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.891  Unzipping done
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:03.891  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.623  Created BiqQuery dataset
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.623  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  1        2                      Jumanji  1995  113497         110   3.431818
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  2        3             Grumpier Old Men  1995  113228          52   3.259615
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  3        4            Waiting to Exhale  1995  114885           7   2.357143
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  4        5  Father of the Bride Part II  1995  113041          49   3.071429
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:04.864  Creating bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:05.099  Populating bdcc20-p1.tiny1.movies_agg with 10 rows
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:07.509  waiting for load job to complete
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:08.578  waiting for load job to complete
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:09.730  waiting for load job to complete
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:10.840  waiting for load job to complete
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:12.029  waiting for load job to complete
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:13.089  Done with table bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:13.089  tfidf data loading is not implemented!
# I      loader_cloud_function  1087568208062703  2020-03-31 15:17:13.089  Done for data set tiny1
# D      loader_cloud_function  1087568208062703  2020-03-31 15:17:13.093  Function execution took 9262 ms, finished with status: 'ok'
# D      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.465  Function execution started
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.473  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.473  Context: {event_id: 1087549803900413, timestamp: 2020-03-31T15:18:50.043Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.473  Dataset: tiny1
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.473  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.485  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.491  Unzipping done
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:50.491  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.123  Created BiqQuery dataset
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.123  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276  1        2                      Jumanji  1995  113497         110   3.431818
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276  2        3             Grumpier Old Men  1995  113228          52   3.259615
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276  3        4            Waiting to Exhale  1995  114885           7   2.357143
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.276  4        5  Father of the Bride Part II  1995  113041          49   3.071429
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.277  Creating bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:51.560  Populating bdcc20-p1.tiny1.movies_agg with 10 rows
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:53.558  waiting for load job to complete
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:54.735  waiting for load job to complete
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:55.838  waiting for load job to complete
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:56.913  waiting for load job to complete
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:58.060  Done with table bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:58.060  tfidf data loading is not implemented!
# I      loader_cloud_function  1087549803900413  2020-03-31 15:18:58.060  Done for data set tiny1
# D      loader_cloud_function  1087549803900413  2020-03-31 15:18:58.064  Function execution took 7600 ms, finished with status: 'ok'
# D      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.259  Function execution started
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.269  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.269  Context: {event_id: 1087550550916460, timestamp: 2020-03-31T15:22:34.786Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.269  Dataset: tiny1
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.269  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.284  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.290  Unzipping done
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:35.290  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.060  Created BiqQuery dataset
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.060  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  1        2                      Jumanji  1995  113497         110   3.431818
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  2        3             Grumpier Old Men  1995  113228          52   3.259615
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  3        4            Waiting to Exhale  1995  114885           7   2.357143
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  4        5  Father of the Bride Part II  1995  113041          49   3.071429
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.362  Creating bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:36.660  Populating bdcc20-p1.tiny1.movies_agg with 10 rows
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:38.526  waiting for load job to complete
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:39.612  waiting for load job to complete
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:40.660  waiting for load job to complete
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:41.851  waiting for load job to complete
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:42.935  waiting for load job to complete
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:44.016  Done with table bdcc20-p1.tiny1.movies_agg
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:44.016  tfidf data loading is not implemented!
# I      loader_cloud_function  1087550550916460  2020-03-31 15:22:44.016  Done for data set tiny1
# D      loader_cloud_function  1087550550916460  2020-03-31 15:22:44.018  Function execution took 8760 ms, finished with status: 'ok'
# D      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.159  Function execution started
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.170  Event: {'@type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage', 'attributes': None, 'data': 'dGlueTE='}
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.170  Context: {event_id: 1087569182130285, timestamp: 2020-03-31T15:26:43.669Z, event_type: google.pubsub.topic.publish, resource: {'service': 'pubsub.googleapis.com', 'name': 'projects/bdcc20-p1/topics/dispatcher', 'type': 'type.googleapis.com/google.pubsub.v1.PubsubMessage'}}
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.170  Dataset: tiny1
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.170  Downloading gs://bdcc1920_project_outputs/tiny1/output.zip to /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.486  Unzipping /tmp/LCF_2yfv9one/output.zip
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.567  Unzipping done
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:44.567  Deleting previous BiqQuery dataset (if any)
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:45.207  Created BiqQuery dataset
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:45.207  Reading Parquet files from /tmp/LCF_2yfv9one/movies_agg.parquet
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:45.390     movieId                        title  year  imdbId  numRatings  avgRating
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:45.390  0        1                    Toy Story  1995  114709         215   3.920930
# I      loader_cloud_function  1087569182130285  2020-03-31 15:26:45.390  1        2                      Jumanji  1995  113497         110   3.431818
#
#
# Command killed by keyboard interrupt
#
# ^C

# %%
# %%bigquery "magics". pandas dataframe
# %%bigquery --project $PROJECT_ID
SELECT *
FROM `bdcc20-p1.tiny1.tfidf`
LIMIT 10

'''
# dataframe objects
# %%bigquery --project $PROJECT_ID tfidf_df
SELECT *
FROM `bdcc20-p1.tiny1.tfidf`
LIMIT 10
'''
# Out:
# Executing query with job ID: 788f30ab-158a-4463-9c49-c0e2dffe139a
# Query executing: 0.20s
# ERROR:
#  400 Syntax error: Unexpected string literal '''\n# dataframe objects\n%%bigquery --project ...''' at [5:1]
#
# (job ID: 788f30ab-158a-4463-9c49-c0e2dffe139a)
#
#        -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |
#    1:SELECT *
#    2:FROM `bdcc20-p1.tiny1.tfidf`
#    3:LIMIT 10
#    4:
#    5:'''
#    6:# dataframe objects
#    7:%%bigquery --project $PROJECT_ID tfidf_df
#    8:SELECT *
#    9:FROM `bdcc20-p1.tiny1.tfidf`
#   10:LIMIT 10
#   11:'''
#     |    .    |    .    |    .    |    .    |

# %%
# %%bigquery "magics". pandas dataframe
# %%bigquery --project $PROJECT_ID
SELECT *
FROM `bdcc20-p1.medium1.tfidf`
LIMIT 10

'''
# dataframe objects
# %%bigquery --project $PROJECT_ID tfidf_df
SELECT *
FROM `bdcc20-p1.medium1.tfidf`
LIMIT 10
'''
# Out:
# Executing query with job ID: 232f4751-ae32-444d-bfb7-e466d9dde396
# Query executing: 0.24s
# ERROR:
#  400 Syntax error: Unexpected string literal '''\n# dataframe objects\n%%bigquery --project ...''' at [5:1]
#
# (job ID: 232f4751-ae32-444d-bfb7-e466d9dde396)
#
#        -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |
#    1:SELECT *
#    2:FROM `bdcc20-p1.medium1.tfidf`
#    3:LIMIT 10
#    4:
#    5:'''
#    6:# dataframe objects
#    7:%%bigquery --project $PROJECT_ID tfidf_df
#    8:SELECT *
#    9:FROM `bdcc20-p1.medium1.tfidf`
#   10:LIMIT 10
#   11:'''
#     |    .    |    .    |    .    |    .    |

# %%
from google.cloud import bigquery
client = bigquery.Client(project=PROJECT_ID)

# %%
for d_info in client.list_datasets():
   print('Dataset ' + d_info.full_dataset_id)
# Out:
# Dataset bdcc20-p1:medium1
# Dataset bdcc20-p1:tiny1

# %%
madf = client.query(
  '''
  SELECT *
  FROM `bdcc20-p1.tiny1.tfidf`
  LIMIT 10
  '''
)
madf.to_dataframe()
# Out:
#                word  movieId     tfidf
# 0             pixar        1  2.321928
# 1              game        2  2.321928
# 2           fantasy        2  2.321928
# 3    Robin Williams        2  2.321928
# 4  magic board game        2  2.321928
# 5             moldy        3  2.321928
# 6               old        3  2.321928
# 7         pregnancy        5  2.321928
# 8               fun        1  1.160964
# 9            remake        5  1.321928

# %%
madf = client.query(
  '''
  SELECT *
  FROM `bdcc20-p1.medium1.tfidf`
  LIMIT 10
  '''
)
madf.to_dataframe()
# Out:
#                  word  movieId     tfidf
# 0  strong female lead     3408  2.062177
# 1              unique    26326  2.062177
# 2              Comedy    95441  1.959410
# 3         predictable    95441  3.473214
# 4             revenge    68157  0.818961
# 5             disease    48043  1.021024
# 6   alternate history    68157  2.285392
# 7        twist ending     1687  0.783018
# 8        Diane Kruger    68157  0.761797
# 9            anti-war     2890  7.617973

# %%
madf = client.query(
  '''
  SELECT *
  FROM `bdcc20-p1.tiny1.jaccardIndex`
  LIMIT 10
  '''
)
madf.to_dataframe()
# Out:
#    movie1  movie2  user  index  jaccard_index
# 0       1       6   189     27       0.142857
# 1       1       2   176     21       0.119318
# 2       1      10   187     19       0.101604
# 3       1       3   154     11       0.071429
# 4       1       5   152      7       0.046053
# 5       1       7   160      7       0.043750
# 6       2      10   100      9       0.090000
# 7       2       6   111      8       0.072072
# 8       2       7    64      6       0.093750
# 9       2       3    63      5       0.079365

# %%
madf = client.query(
  '''
  SELECT *
  FROM `bdcc20-p1.medium1.jaccardIndex`
  LIMIT 10
  '''
)
madf.to_dataframe()
# Out:
#    movie1  movie2   user  index  jaccard_index
# 0   95441  126430   1958     46       0.023493
# 1  126430  140737    539     16       0.029685
# 2   95441   96367   1689     13       0.007697
# 3    2058    3052  14767   1110       0.075168
# 4    2058    3408  14461   1096       0.075790
# 5    2058    2890  11640   1019       0.087543
# 6    2058    4720  12326    739       0.059955
# 7    2058    5502   9820    658       0.067006
# 8    2058   68157  20860    641       0.030729
# 9    2058    2447   6154    238       0.038674
